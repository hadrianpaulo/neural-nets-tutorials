# %% [markdown]
# # Convolutional Neural Networks with Keras

# %% [markdown]
# ## What is it?
# Convolutional Neural Networks (CNN / ConvNet) are very similar to our regular Artificial Neural Networks. It also has learnable weights and biases.
#
# Still consists the following steps:
#
# 1. Accepts vector of inputs
# 2. Performs dot multiplications
# 3. Subjection to an activation function
# 4. Class scores
# 5. Loss function
# 6. Back propagation to update weights and biases
#
# ## How is it different to our regular ANN then?
#
# __CNN is specifically catered to images.__ Remember, unlike regular input vectors, each pixel in an image has 3 color channels representing colors Red, Green, and Blue.
#
# > _Regular Neural Nets don’t scale well to full images_. In CIFAR-10, images are only of size 32x32x3 (32 wide, 32 high, 3 color channels), so a single fully-connected neuron in a first hidden layer of a regular Neural Network would have 32*32*3 = 3072 weights. This amount still seems manageable, but clearly this fully-connected structure does not scale to larger images. For example, an image of more respectable size, e.g. 200x200x3, would lead to neurons that have 200*200*3 = 120,000 weights. Moreover, we would almost certainly want to have several such neurons, so the parameters would add up quickly! Clearly, this full connectivity is wasteful and the huge number of parameters would quickly lead to overfitting. -- Andrej Karpathy
#
# Regular Neural Networks doesn't take into advantage the architecture of images. Tendency is to have an 1) explosion on the number of neurons -- multiplicative effect on the processing for network parameters, and 2) overfitting.
#
# > _3D volumes of neurons_. Unlike a regular Neural Network, the layers of a ConvNet have neurons arranged in 3 dimensions: width, height, depth (depth of activation volume, not the layers). For example, the input images in CIFAR-10 are an input volume of activations, and the volume has dimensions 32x32x3 (width, height, depth respectively). As we will soon see, the neurons in a layer will only be connected to a small region of the layer before it, instead of all of the neurons in a fully-connected manner. Moreover, the final output layer would for CIFAR-10 have dimensions 1x1x10, because by the end of the ConvNet architecture we will reduce the full image into a single vector of class scores, arranged along the depth dimension. Here is a visualization: -- Andrej Karpathy
#
# Convolutional Neural Network treats the inputs as __volumes__ making the architecture more manageable.
#
# <img src="figs/L4/ann_vs_cnn.png" alt="ANN VS CNN" style="width: 75%;"/>
#
# ## How does a ConvNet work?
#
# There are four main operations in the ConvNet, namely:
#
# 1. Convolution
# 2. Activation / Non Linearity (ReLU)
# 3. Pooling or Sub Sampling
# 4. Classification (Fully Connected Layer)
#
# <img src="figs/L4/cnn_parts.png" alt="cnn_parts" style="width: 75%;"/>
#
# You can look at a nice visualization [Vis](http://scs.ryerson.ca/~aharley/vis/conv/) by Adam Harley.
#
# ## 1. Convolution
#
# > Imagine a flashlight that is shining over the top left of the image. Let’s say that the light this flashlight shines covers a __5 x 5__ area. And now, let’s imagine this flashlight sliding across all the areas of the input image. In machine learning terms, this flashlight is called a __filter__ and the region that it is shining over is called the __receptive field__. Now this __filter is also an array of numbers__ (the numbers are called weights or parameters). A very important note is that the __depth of this filter has to be the same as the depth of the input__ (remember dot product requirement?), so the dimensions of this filter is __5 x 5 x 3__. Now, let’s take the first position the filter is in for example. As the filter is sliding, or __convolving__, around the input image, it is __multiplying the values in the filter with the original pixel values__ of the image (aka computing element wise multiplications). These multiplications are all __summed up to end up with a single number__. Remember, this number is just representative of when the filter is at the top left of the image. Now, we repeat this process for every location on the input volume. Next step would be moving the filter to the right by 1 unit, then right again by 1, and so on. Every unique location on the input volume produces a number.
#
# > Let's say that the input image has a dimension of 32 x 32 x 3, then after the convolution is done, we'll be left with 28 x 28 x 1 array of numbers, which we call an __activation map__ or __feature map__.
#
# Convolution's goal is to extract the __features__. Considering an input grayscale (1 channel) image
# <img src="figs/L4/input_ex.png" alt="Input image example" style="width: 20%;"/>
#
# and a filter matrix below
# <img src="figs/L4/filter_ex.png" alt="Filter image example" style="width: 10%;"/>
#
# Convolving would look like:
# <img src="figs/L4/convolution.gif" alt="Convolution in GIF" style="width: 50%;"/>
#
# Another example would be:
# <img src="figs/L4/convolution_2.gif" alt="Convolution in GIF" style="width: 50%;"/>
#
# Each of the filters can be thought of as __features identifiers__ wherein features are straight edges, curves, colors, etc.
#
# ### Parameters for convolution (Hyperparameters)
# 1. Depth - corresponds to the number of filters we use for the convolution operation.
# <img src="figs/L4/depth.png" alt="Depth" style="width: 50%;"/>
#
# 2. Stride - number of pixels by which we slide our filter matrix over the input matrix. When the stride is 1 then we move the filters one pixel at a time. When the stride is 2, then the filters jump 2 pixels at a time as we slide them around. Having a larger stride will produce smaller feature maps.
#
# 3. Zero-padding - Sometimes, it is convenient to pad the input matrix with zeros around the border, so that we can apply the filter to bordering elements of our input image matrix. A nice feature of zero padding is that it allows us to control the size of the feature maps. Adding zero-padding is also called wide convolution, and not using zero-padding would be a narrow convolution.
#
# ### How does convolving give us the features?
# Let's say we want to have a curve detector. For simplicity, let's just consider a greyscale image (1 channel).
# <img src="figs/L4/filter_ex_1.png" alt="Filter image example" style="width: 60%;"/>
#
# Now, let's say we have an input image below with the filter on the top left corner.
# <img src="figs/L4/input_ex_1.png" alt="Input image example" style="width: 70%;"/>
#
# Remember, what we have to do is multiply the values in the filter with the original pixel values of the image and add them all up to have a single numeric value representing the receptive field.
# <img src="figs/L4/mult.png" alt="Mult example" style="width: 70%;"/>
#
# Basically, in the input image, if there is a shape that generally resembles the curve that this filter is representing, then all of the multiplications summed together will result in a large value! Now let’s see what happens when we move our filter.
# <img src="figs/L4/mult_1.png" alt="Mult example" style="width: 70%;"/>
#
# The value then becomes 0. This means that the __image section didn't respond to the curve detector filter__ -- or activated. Remember, the output of this conv layer is an activation map. So, in the simple case of a one filter convolution (and if that filter is a curve detector), the activation map will __show the areas in which there at mostly likely to be curves in the picture.__
#
# This is just for one filter that detects curves of that shape. We can employ more filters. The __more filters__, the __greater the depth_ of activation map -> the more information we have abour our input volume.
#
# Below are some examples of filters.
# <img src="figs/L4/filters.png" alt="Filters examples" style="width: 30%;"/>
#
#
# ## Hold up. That's already a lot! Let's synthesize for a while.
#
# * __Filters__ in the __first conv layer__ are designed to __detect low level features__ such as edges and curves
# * But, in order to predict whether an image is a type of object, we need the network to be able to __recognize higher level features__ such as hands or paws or ears.
# * For the __first layer__, the __input was just the original image__. However, when we’re talking about the __succeeding layers__, the input will then be the __activation maps of the immediate layer before__.
# * Each layer of the input is basically describing the locations in the original image for where certain low level features appear. When you __apply a set of filters on top of that__, the output will be __activations that represent higher level features__ - semicircles (combination of a curve and straight edge) or squares (combination of several straight edges).
# * As you go through the network and go through more conv layers, you get activation maps that represent __more and more complex features__. By the end of the network, you may have some filters that activate when there is handwriting in the image
# * Another interesting thing to note is that as you go deeper into the network, the filters begin to have a __larger and larger receptive field__, which means that they become more responsive to a larger region of pixel space.
#
# ## Going back...
# ## 2. Activation / Non-linearity Functions
# <img src="figs/L4/cnn_parts.png" alt="cnn_parts" style="width: 75%;"/>
#
# Like our ANN, CNN feature maps (from dot products) can have values ranging from -inf to +inf. So how would we know when a neuron will fire or not if we don't know the bounds of the values? -- Activation functions.
#
# In the figure below, __ReLU activation function__ was used. This is useful as ReLU will introduce non-linearity behavior in our network.
#
# More about [activation functions here](https://medium.com/the-theory-of-everything/understanding-activation-functions-in-neural-networks-9491262884e0).
#
#
# ## 3. Pooling / Subsampling
#
# Spatial Pooling (also called subsampling or downsampling) __reduces the dimensionality__ of the feature map __while retaining__ the most important information. Spatial Pooling can be of different types: Max, Average, Sum etc. In practice, __Max Pooling__ has shown to work better.
#
# <img src="figs/L4/max_pooling.png" alt="Max Pooling" style="width: 60%;"/>
#
# So if we look at it at our network level, pooling operation will be applied to each feature map.
# <img src="figs/L4/max_pooling_2.png" alt="Max Pooling" style="width: 60%;"/>
#
# Example of pooling operation effect on a rectified image
# <img src="figs/L4/max_pooling_3.png" alt="Max Pooling" style="width: 60%;"/>
#
# ### Why do we need to pool / subsample?
# 1. Makes our feature dimensions smaller == manageable
# 2. Reduces the number of operations, hence controlling overfitting
# 3. Makes our network less sensitive to noise or distortions
# 4. "Equivariant"
# >Helps us arrive at an almost scale invariant representation of our image (the exact term is “equivariant”). This is very powerful since we can detect objects in an image no matter where they are located
#
# ## Lastly..
# <img src="figs/L4/cnn_parts.png" alt="cnn_parts" style="width: 75%;"/>
#
# ## 4. Fully Connected Layer
# >The output from the convolutional and pooling layers represent high-level features of the input image. The purpose of the Fully Connected layer is to use these features for classifying the input image into various classes based on the training dataset.
#
# <img src="figs/L4/fc.png" alt="Fully Connected Layer" style="width: 50%;"/>
#
# Aside from using this layer for classification, it can also be used to learn __non-linear combinations__ of the features. Most commonly used activation function in the output layer is the __Softmax function__. _Remember what Softmax function does?_
#
# ## Putting it all together
# 1. Convolution + Activation / Non Linearity (ReLU) -- Feature extractors. The deeper the network is, the more complex our extracted featues get (from curves to paws)
# 3. Pooling or Sub Sampling - Makes our computations easier, lessens overfitting.
# 4. Classification (Fully Connected Layer) - Classifier and an easy way to learn non-linearity
# 5. Backpropagation - update weights by comparing the output with the target
#
# <img src="figs/L4/training.png" alt="Training" style="width: 75%;"/>

# %% [markdown]
# # Wew. Break.
#
# <img src="figs/L4/xkcd.png" alt="xkcd" style="width: 50%;"/>
# [Link](https://xkcd.com/1838/)

# %% [markdown]
# ## Simple CNN for MNIST Dataset
#
# The __MNIST dataset__ is used in evaluating machine learning models on the __handwritten digit classification problem__. This was constructed from a number of scanned document dataset available from the __National Institute of Standards and Technology (NIST)__, where the name for the dataset comes from - __Modified NIST__ or __MNIST dataset__.
#
# Each image is a 28 by 28 pixel square (784 pixels total). A standard split of __60,000 images for training__ a model and a separate set of __10,000 images for testing__ a model is provided.
#
# Goal: Digit recognition task. As such there are 10 digits (0 to 9) or 10 classes to predict.
#
# Excellent results achieve a prediction error of less than 1%. State-of-the-art prediction error of approximately 0.2% can be achieved with large Convolutional Neural Networks. There is a listing of the state-of-the-art results and links to the relevant papers on the MNIST and other datasets on Rodrigo Benenson’s webpage - Machine Learning Mastery

# %% [markdown]
# Importing dataset

# %%
# %pylab inline

import numpy
import matplotlib.pyplot as plt

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K

K.set_image_dim_ordering('th')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using TensorFlow backend.

# %% [markdown]
# Fix random seed for reproducibility

# %%
seed = 7
numpy.random.seed(seed)

# %% [markdown]
# Let's look at some of the MNIST images by plotting them!

# %%
# load (downloaded if needed) the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# plot 4 images as gray scale
plt.subplot(221)
plt.imshow(X_train[0], cmap=plt.get_cmap('gray'))
plt.subplot(222)
plt.imshow(X_train[1], cmap=plt.get_cmap('gray'))
plt.subplot(223)
plt.imshow(X_train[2], cmap=plt.get_cmap('gray'))
plt.subplot(224)
plt.imshow(X_train[3], cmap=plt.get_cmap('gray'))
# show the plot
plt.show()

# %% [markdown]
# Next we need to load the MNIST dataset and reshape it so that it is suitable for use training a CNN. In Keras, the layers used for two-dimensional convolutions expect pixel values with the dimensions [pixels][width][height].
#
# In the case of RGB, the first dimension pixels would be 3 for the red, green and blue components and it would be like having 3 image inputs for every color image. In the case of MNIST where the pixel values are gray scale, the pixel dimension is set to 1.

# %%
# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 1, 28, 28).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 1, 28, 28).astype('float32')

# %% [markdown]
# As before, it is a good idea to normalize the pixel values to the range 0 and 1 and one hot encode the output variables.

# %%
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %% [markdown]
# Next we define our neural network model.
#
# Convolutional neural networks are more complex than standard multi-layer perceptrons, so we will start by using a simple structure to begin with that uses all of the elements for state of the art results. Below summarizes the network architecture.
#
# 1. The first hidden layer is a convolutional layer called a Convolution2D. The layer has 32 feature maps, which with the size of 5×5 and a rectifier activation function. This is the input layer, expecting images with the structure outline above [pixels][width][height].
# 2. Next we define a pooling layer that takes the max called MaxPooling2D. It is configured with a pool size of 2×2.
# 3. The next layer is a regularization layer using dropout called Dropout. It is configured to randomly exclude 20% of neurons in the layer in order to reduce overfitting.
# 4. Next is a layer that converts the 2D matrix data to a vector called Flatten. It allows the output to be processed by standard fully connected layers.
# 5. Next a fully connected layer with 128 neurons and rectifier activation function.
# 6.Finally, the output layer has 10 neurons for the 10 classes and a softmax activation function to output probability-like predictions for each class.
#
# The model is trained using logarithmic loss and the ADAM gradient descent algorithm.

# %%
def baseline_model():
    # create model
    model = Sequential()
    model.add(Conv2D(32, (5, 5), input_shape=(1, 28, 28), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# We evaluate the model the same way as before with the multi-layer perceptron. The CNN is fit over 10 epochs with a batch size of 200.
#
# Running the example, the accuracy on the training and validation test is printed each epoch and at the end of the classification error rate is printed.

# %%
# Building a model
model = baseline_model()
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 169s - loss: 0.2454 - acc: 0.9298 - val_loss: 0.0730 - val_acc: 0.9781
# Epoch 2/10
# 174s - loss: 0.0735 - acc: 0.9783 - val_loss: 0.0487 - val_acc: 0.9852
# Epoch 3/10
# 174s - loss: 0.0525 - acc: 0.9844 - val_loss: 0.0397 - val_acc: 0.9875
# Epoch 4/10
# 175s - loss: 0.0398 - acc: 0.9879 - val_loss: 0.0389 - val_acc: 0.9874
# Epoch 5/10
# 175s - loss: 0.0340 - acc: 0.9894 - val_loss: 0.0459 - val_acc: 0.9862
# Epoch 6/10
# 177s - loss: 0.0278 - acc: 0.9914 - val_loss: 0.0347 - val_acc: 0.9889
# Epoch 7/10
# 176s - loss: 0.0231 - acc: 0.9924 - val_loss: 0.0340 - val_acc: 0.9891
# Epoch 8/10
# 156s - loss: 0.0203 - acc: 0.9937 - val_loss: 0.0296 - val_acc: 0.9905
# Epoch 9/10
# 141s - loss: 0.0173 - acc: 0.9943 - val_loss: 0.0369 - val_acc: 0.9894
# Epoch 10/10
# 140s - loss: 0.0152 - acc: 0.9949 - val_loss: 0.0308 - val_acc: 0.9902
# Test loss: 0.0308127043182
# Test accuracy: 0.9902

# %% [markdown]
# ## Larger Convolutional Neural Network for MNIST

# %%
# Larger CNN for the MNIST Dataset
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 1, 28, 28).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 1, 28, 28).astype('float32')
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %% [markdown]
# This time we define a large CNN architecture with additional convolutional, max pooling layers and fully connected layers. The network topology can be summarized as follows.
#
# 1. Convolutional layer with 30 feature maps of size 5×5.
# 2. Pooling layer taking the max over 2*2 patches.
# 3. Convolutional layer with 15 feature maps of size 3×3.
# 4. Pooling layer taking the max over 2*2 patches.
# 5. Dropout layer with a probability of 20%.
# 6. Flatten layer.
# 7. Fully connected layer with 128 neurons and rectifier activation.
# 8. Fully connected layer with 50 neurons and rectifier activation.
# 8. Output layer.

# %%
# define the larger model
def larger_model():
    # create model
    model = Sequential()
    model.add(Conv2D(30, (5, 5), input_shape=(1, 28, 28), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(15, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# Like the previous experiment, the model is fit over 10 epochs with a batch size of 200.

# %%
# build the model
model = larger_model()
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 156s - loss: 0.3920 - acc: 0.8799 - val_loss: 0.1012 - val_acc: 0.9664
# Epoch 2/10
# 60000/60000 [==============================] - 156s - loss: 0.0945 - acc: 0.9712 - val_loss: 0.0578 - val_acc: 0.9805
# Epoch 3/10
# 60000/60000 [==============================] - 161s - loss: 0.0683 - acc: 0.9792 - val_loss: 0.0373 - val_acc: 0.9885
# Epoch 4/10
# 60000/60000 [==============================] - 158s - loss: 0.0555 - acc: 0.9827 - val_loss: 0.0322 - val_acc: 0.9887
# Epoch 5/10
# 60000/60000 [==============================] - 159s - loss: 0.0474 - acc: 0.9849 - val_loss: 0.0295 - val_acc: 0.9908
# Epoch 6/10
# 60000/60000 [==============================] - 160s - loss: 0.0432 - acc: 0.9861 - val_loss: 0.0286 - val_acc: 0.9899
# Epoch 7/10
# 60000/60000 [==============================] - 174s - loss: 0.0376 - acc: 0.9880 - val_loss: 0.0268 - val_acc: 0.9908
# Epoch 8/10
# ...

# %% [markdown]
# ### Take (me) away
#
# * CNN is ANN made specially for images
# * Main process added is convolution -- making our inputs turn into volume
# * Like ANN, there are also a lot of hyperparameters to play with. Some new parameters are the convolution stride, filter size, depth, padding, pooling size, and pooling type.

# %% [markdown]
# Credits to the following excellent blog sites:
#
# * [Adit Deshpande](https://adeshpande3.github.io/adeshpande3.github.io/A-Beginner%27s-Guide-To-Understanding-Convolutional-Neural-Networks/) -- Intuitive explanation and analogies for CNN.
# * [Ujjwal Karn](https://ujjwalkarn.me/2016/08/11/intuitive-explanation-convnets/) -- Intuitive explanation and analogies for CNN. A bit deeper than Adit Deshpande's.
# * [Andrej Karpathy](http://cs231n.github.io/convolutional-networks/) -- Theories
# * [Machine Learning Mastery](http://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/) -- MNIST Keras code
